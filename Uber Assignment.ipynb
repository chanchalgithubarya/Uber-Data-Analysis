# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
uber = pd.read_csv(r"C:\Users\Dell\Documents\ALAB Python Programing Alab\Class _ 21-22-23\uberdrive.csv")
uber
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# # Q1. Show the last 10 records of the dataset.

# %%
uber[-10:]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Karachi      2.9  Errand/Supplies
# 1147           Karachi      4.6  Errand/Supplies
# 1148           Karachi      4.6          Meeting
# ...

# %%
uber.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Karachi      2.9  Errand/Supplies
# 1147           Karachi      4.6  Errand/Supplies
# 1148           Karachi      4.6          Meeting
# ...

# %% [markdown]
# # Q2. Show the first 10 records of the dataset

# %%
uber[:10]
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %%
uber.head(10)
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %% [markdown]
# # Q3. Show the dimension of the dataset.

# %%
uber.shape
# Out:
# (1156, 7)

# %% [markdown]
# # Q4. Show the size of the dataset.

# %%
uber.size
# Out:
# 8092

# %% [markdown]
# # Q5. Print the information about all the variables of the data set.

# %%
uber.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %% [markdown]
# # Q6. Check for missing values.

# %%
uber.isnull().values.any()
# Out:
# True

# %% [markdown]
# # Q7. How many missing values are present?

# %%
uber.isnull().values.sum()
# Out:
# 507

# %% [markdown]
# # Q8. Get the initial data (name it 'df') with dropping the NA values

# %%
df = uber.dropna()
df.isna().values.any()
# Out:
# False

# %% [markdown]
# # Q9. Get the summary of the original data (before dropping the 'na' values).

# %%
uber.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %% [markdown]
# # Q10. Check the information of the new dataframe.

# %%
df.describe()
# Out:
#            MILES*
# count  653.000000
# mean    11.196325
# std     22.986429
# min      0.500000
# 25%      3.200000
# 50%      6.400000
# 75%     10.400000
# max    310.300000

# %% [markdown]
# # Q11. Get the unique start destinations
# ## Note: This question is based on the dataframe with 'na' values in the 'START*' variable.

# %%
unique_start = uber["START*"].dropna()
unique_start_dest = set(unique_start)
unique_start_dest
# Out:
# {'Agnew',
#  'Almond',
#  'Apex',
#  'Arabi',
#  'Arlington',
#  'Arlington Park at Amberly',
#  'Asheville',
#  'Austin',
#  'Banner Elk',
#  'Bellevue',
#  'Berkeley',
#  'Boone',
#  'Briar Meadow',
#  'Bryson City',
#  'Burtrose',
#  'CBD',
#  'Capitol One',
#  'Cary',
#  'Central',
#  'Chalmette',
#  'Chapel Hill',
#  'Chessington',
#  'College Avenue',
#  'Colombo',
#  'Columbia Heights',
#  'Congress Ave District',
#  'Connecticut Avenue',
#  'Convention Center District',
#  'Cory',
#  'Couples Glen',
#  'Covington',
#  'Coxville',
#  'Daytona Beach',
#  'Downtown',
#  'Durham',
#  'Eagan Park',
#  'Eagle Rock',
#  'East Austin',
#  'East Elmhurst',
#  'East Harlem',
#  'Eastgate',
#  'Edgehill Farms',
#  'El Cerrito',
#  'Elk Park',
#  'Elmhurst',
#  'Emeryville',
#  'Fairmont',
#  'Farmington Woods',
#  'Fayetteville Street',
#  'Financial District',
#  'Flatiron District',
#  'Florence',
#  'Fort Pierce',
#  'Fuquay-Varina',
#  'Galveston',
#  'Gampaha',
# ...

# %% [markdown]
# # Q12. What is the total number of unique start destinations?

# %%
len(unique_start_dest)
# Out:
# 176

# %% [markdown]
# # Q13. Print the total number of unique stop destinations
# ## Note: This question is based on the dataframe with No 'na' values in the 'START*' variable.

# %%
unique_stop = uber["STOP*"].dropna()
unique_stop_dest = set(unique_stop)
unique_stop_dest
# Out:
# {'Agnew',
#  'Alief',
#  'Almond',
#  'Apex',
#  'Arabi',
#  'Arlington',
#  'Arlington Park at Amberly',
#  'Arts District',
#  'Asheville',
#  'Banner Elk',
#  'Bay Farm Island',
#  'Bellevue',
#  'Berkeley',
#  'Boone',
#  'Briar Meadow',
#  'Bryson City',
#  'Burtrose',
#  'Bywater',
#  'CBD',
#  'Capitol One',
#  'Cary',
#  'Cedar Hill',
#  'Central',
#  'Chalmette',
#  'Chapel Hill',
#  'Chessington',
#  'College Avenue',
#  'Colombo',
#  'Columbia Heights',
#  'Congress Ave District',
#  'Convention Center District',
#  'Cory',
#  'Covington',
#  'Coxville',
#  'Daytona Beach',
#  'Depot Historic District',
#  'Downtown',
#  'Durham',
#  'Eagle Rock',
#  'East Elmhurst',
#  'East Harlem',
#  'Edgehill Farms',
#  'El Cerrito',
#  'Elk Park',
#  'Emeryville',
#  'Farmington Woods',
#  'Faubourg Marigny',
#  'Financial District',
#  'Florence',
#  'Fort Pierce',
#  'French Quarter',
#  'Fuquay-Varina',
#  'Galveston',
#  'Gampaha',
#  'Gramercy-Flatiron',
# ...

# %%
len(unique_stop_dest)
# Out:
# 187

# %% [markdown]
# # Q14. Print all the Uber trips that has the starting point of San Francisco.
# ## Note: use the original dataframe without dropping 'na' values.

# %%
uber.loc[uber['START*']=='San Francisco']
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# # Q15. What is the most popular starting point for the Uber drivers?
# ## Note: This question is based on dataframe with no 'na' values in the 'START' variable

# %%
starting_point = df['START*'].dropna()
pop_start_point = pd.DataFrame(starting_point.value_counts()).sort_values('START*',ascending=False).reset_index()
pop_start_point.rename(columns={'index':'Starting Point','START*':'Count'}).head(1)
# Out:
#   Starting Point  Count
# 0           Cary    161

# %% [markdown]
# # Q16. What is the most popular dropping point for the Uber drivers?
# ## Note: This question is based on dataframe with no 'na' values in the 'STOP*' variable

# %%
stop_point = df['STOP*'].dropna()
pop_stop_point= pd.DataFrame(stop_point.value_counts()).sort_values('STOP*',ascending=False).reset_index().rename(columns={'index':'Dropping Point','STOP*':'Count'})

pop_stop_point.loc[pop_stop_point['Count'] == max(pop_stop_point['Count'])]
# Out:
#   Dropping Point  Count
# 0           Cary    155

# %% [markdown]
# # Q17. List the most frequent route taken by Uber drivers.
# ## Note: This question is based on dataframe with no 'na' values.

# %%
df2 = df.dropna()
freq_route = pd.DataFrame(df2.groupby(['STOP*',"START*"]).size()).rename(columns={0:'Count'})

freq_route = freq_route.sort_values('Count',ascending=False).head(1)
freq_route
# Out:
#                     Count
# STOP*       START*
# Morrisville Cary       52

# %% [markdown]
# # Q18. Print all types of purposes for the trip in an array.
# ## Note: This question is based on dataframe with no 'na' values in the 'PURPOSE*' variable.

# %%
print(np.array(df['PURPOSE*'].dropna().unique()))
df.groupby('PURPOSE*')[['MILES*']].sum().reset_index().sort_values(by='MILES*',ascending=False)
# Out:
# ['Meal/Entertain' 'Errand/Supplies' 'Meeting' 'Customer Visit'
#  'Temporary Site' 'Between Offices' 'Charity ($)' 'Commute' 'Moving'
#  'Airport/Travel']
#           PURPOSE*  MILES*
# 7          Meeting  2851.3
# 4   Customer Visit  2089.5
# 6   Meal/Entertain   911.7
# 9   Temporary Site   523.7
# 5  Errand/Supplies   508.0
# 1  Between Offices   197.0
# 3          Commute   180.2
# 8           Moving    18.2
# 0   Airport/Travel    16.5
# 2      Charity ($)    15.1

# %% [markdown]
# # Q19. Plot a bar graph of Purposes vs Distance.
# ## Note: This question is based on the original dataframe.

# %%
df3 = uber.groupby('PURPOSE*')[['MILES*']].sum().reset_index().sort_values(by='MILES*',ascending=False).rename(columns={'MILES*':'Distance'})

# %%
df3
# Out:
#           PURPOSE*  Distance
# 7          Meeting    2851.3
# 4   Customer Visit    2089.5
# 6   Meal/Entertain     911.7
# 9   Temporary Site     523.7
# 5  Errand/Supplies     508.0
# 1  Between Offices     197.0
# 3          Commute     180.2
# 8           Moving      18.2
# 0   Airport/Travel      16.5
# 2      Charity ($)      15.1

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Distance', y='PURPOSE*', data = df3)
plt.title("Total Distance")
# Out:
# Text(0.5, 1.0, 'Total Distance')

# %% [markdown]
# # Q20. Print a dataframe of Purposes and the distance travelled for that particular Purpose.
# ## Note: This question is based on the original dataframe.

# %%
df3
# Out:
#           PURPOSE*  Distance
# 7          Meeting    2851.3
# 4   Customer Visit    2089.5
# 6   Meal/Entertain     911.7
# 9   Temporary Site     523.7
# 5  Errand/Supplies     508.0
# 1  Between Offices     197.0
# 3          Commute     180.2
# 8           Moving      18.2
# 0   Airport/Travel      16.5
# 2      Charity ($)      15.1

# %% [markdown]
# # Q21. Plot number of trips vs Category of trips.

# %%
df2 = pd.DataFrame(uber['CATEGORY*'].value_counts())
df2
# Out:
#           CATEGORY*
# Business       1078
# Personal         77

# %%
df2.plot(kind='bar')
plt.show()

# %% [markdown]
# # Q22. What is proportion of trips that is Business and what is the proportion of trips that is Personal?
# ## Note: This proportion calculation is with respect to 'Miles' variable.
# ## Note: Based on original dataframe

# %%
df1 = uber.groupby('CATEGORY*').sum()
df1
# Out:
#             MILES*
# CATEGORY*
# Business   11487.0
# Personal     717.7

# %%
Business = df1.iloc[0,0]/(df1.iloc[0,0]+df1.iloc[1,0])
Personal = df1.iloc[1,0]/(df1.iloc[0,0]+df1.iloc[1,0])

print('Business:',Business)
print('Personal:',Personal)
# Out:
# Business: 0.9411947856153777
# Personal: 0.05880521438462235
